# %%
pwd
# Out:
# '/Users/aridamansc/Desktop'

# %%
ls
# Out:
# AI:ML/                               ROBOTICS/
# Aladin.app/                          STAc/
# Arduino IDE.app/                     Untitled.ipynb
# Arduino.app/                         Untitled1.ipynb
# BOOKS/                               Untitled2.ipynb
# Counter-Strike Global Offensive.app/ Visual Studio Code.app/
# EM2/                                 asteroid/
# GR:QFT/                              b22259_ph301/
# IC 272 LAB/                          exoplanet/
# IMPORTANT DOCUMENTS/                 first year/
# MATLAB_R2022b.app/                   untitled
# Quantum computing/                   xray solar burst/

# %%
cd ./exoplanet/
# Out:
# /Users/aridamansc/Desktop/exoplanet

# %%
ls
# Out:
# 2303.09335.pdf              exoTrain.csv
# KSCI-19091-001.pdf          final_exop_data.csv
# Lightkurve.ipynb            kepler90i.pdf
# Untitled.ipynb              kepler_TCE.csv
# __pycache__/                light_curve/
# astronet/                   preprocess.py
# astrowavenet/               preprocess_1.ipynb
# bhaatra/                    prepropprop.ipynb
# box_least_squares/          tess_tce.csv
# confirmed by transit.csv    tf_util/
# confirmed tess planets.csv  third_party/
# download_kep_1.ipynb        util.py
# exoTest.csv

# %%
import pandas as pd
import lightkurve as lk
import matplotlib.pyplot as plt
import numpy as np
from astropy.timeseries import LombScargle
import __future__
import csv
import ast

from exoplanet import util

# %%
data2=pd.read_csv("final_exop_data.csv")

# %%
x=data2['flux'][0][1:-1].split(',')
# Convert the list of strings to a list of integers
x= [float(item) for item in x]
y=ast.literal_eval(data2['time'][0])
plt.scatter(y,x,s=1)
plt.show()
